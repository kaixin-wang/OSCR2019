# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Data Import and Preprocessing

# %%
# read in the data
data = pd.read_csv("Melbourne_housing_FULL.csv")

# %%
# check if read in correctly
data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
# remove entries with missing response value
data = data.loc[data.Price.notna()]
data = data.reset_index()

# %%
# take log transformation to scale down the response
price = np.log(data.Price)
price = price.rename("logprice")
data = pd.concat([data, price], axis = 1)
data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      1  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      4  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      5  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      6  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0           NaN        NaN
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0           NaN        NaN
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#           CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
# plot the boxplots for price
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 6))
fig.suptitle('Boxplots for price and log(price)')
ax1.boxplot(data.Price)
ax2.boxplot(data.logprice)
plt.show()

# %%
plt.figure(figsize = (8, 6))
sns.heatmap(data.corr())
plt.title("correlation heatmap between variables")
plt.show()
